# %% [markdown]
# Please run the cell below and make sure all packages in the cell have been successfully installed.

# %%
import numpy
import scipy
import matplotlib
import pandas
import seaborn
import sklearn
import tensorflow
import keras
